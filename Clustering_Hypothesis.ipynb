# %%
from os.path import dirname, join as pjoin
import scipy.io as sio
from igraph import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree
from scipy.spatial.distance import pdist
from sklearn.metrics.cluster import adjusted_rand_score
import seaborn as sns
from mne.viz import plot_connectivity_circle

# %%
qua_labels = ['000', '100', '200', '210', '020', '120', '001', '101', '021', '121', '002', '012']
ter_labels = ['200', '210', '020', '120', '201', '211', '021', '121', '002', '012', '102', '112']

# %%
filenames_origin = ['Hypothesis1_Elec9', 'Hypothesis1_Elec9-10-11', 'Hypothesis1_Elec45',
             'Hypothesis1_Elec45-46-40', 'Hypothesis1_Elec75', 'Hypothesis1_Elec75-74-82',
            'Hypothesis1_Elec108', 'Hypothesis1_Elec108-109-107', 'Hypothesis2_Elec9',
            'Hypothesis2_Elec9-10-11', 'Hypothesis2_Elec45', 'Hypothesis2_Elec45-46-40',
            'Hypothesis2_Elec75', 'Hypothesis2_Elec75-74-82', 'Hypothesis2_Elec108',
            'Hypothesis2_Elec108-109-107', 'Hypothesis3_Elec9', 'Hypothesis3_Elec9-10-11',
            'Hypothesis3_Elec45', 'Hypothesis3_Elec45-46-40', 'Hypothesis3_Elec75',
            'Hypothesis3_Elec75-74-82', 'Hypothesis3_Elec108', 'Hypothesis3_Elec108-109-107']
filenames_pitch = ['Hypothesis1_Elec9', 'Hypothesis1_Elec9-37-41', 'Hypothesis1_Elec25',
             'Hypothesis1_Elec25-59-56', 'Hypothesis1_Elec34', 'Hypothesis1_Elec34-1-31',
            'Hypothesis1_Elec48', 'Hypothesis1_Elec48-17-16', 'Hypothesis2_Elec9',
            'Hypothesis2_Elec9-37-41', 'Hypothesis2_Elec25', 'Hypothesis2_Elec25-59-56',
            'Hypothesis2_Elec34', 'Hypothesis2_Elec34-1-31', 'Hypothesis2_Elec48',
            'Hypothesis2_Elec48-17-16', 'Hypothesis3_Elec9', 'Hypothesis3_Elec9-37-41',
            'Hypothesis3_Elec25', 'Hypothesis3_Elec25-59-56', 'Hypothesis3_Elec34',
            'Hypothesis3_Elec34-1-31', 'Hypothesis3_Elec48', 'Hypothesis3_Elec48-17-16']

# %%
path = '/home/kaled/NeuroMat/Clustering/NeuroMat_Clustering_EEG'
data_dir = pjoin(dirname(sio.__file__), 'matlab', path)

# %%
mat_fnames_origin_qua = [pjoin(data_dir, 
                               'CompDendro/Origin_Qua/'+filename+'.mat') for filename in filenames_origin]
mat_fnames_origin_ter = [pjoin(data_dir, 
                               'CompDendro/Origin_Ter/'+filename+'.mat') for filename in filenames_origin]
mat_fnames_pitch_qua = [pjoin(data_dir, 
                              'CompDendro/Pitch_Qua/'+filename+'.mat') for filename in filenames_pitch]
mat_fnames_pitch_ter = [pjoin(data_dir, 
                              'CompDendro/Pitch_Ter/'+filename+'.mat') for filename in filenames_pitch]

# %%
mat_contents_origin_qua = [sio.loadmat(mat_fname) for mat_fname in mat_fnames_origin_qua]
mat_contents_origin_ter = [sio.loadmat(mat_fname) for mat_fname in mat_fnames_origin_ter]
mat_contents_pitch_qua = [sio.loadmat(mat_fname) for mat_fname in mat_fnames_pitch_qua]
mat_contents_pitch_ter = [sio.loadmat(mat_fname) for mat_fname in mat_fnames_pitch_ter]

# %%
def heatmap_print(idx, filenames_origin, mat_content):
    print(filenames_origin[idx])
    
    link__ = linkage(mat_content['dis_mat'], method='complete')
    aris_DF = pd.DataFrame(mat_content['dis_mat'])
    sns.clustermap(aris_DF, metric="euclidean", method="complete", row_linkage=link__, col_linkage=link__,
                   cmap="PRGn", col_cluster=True)
    plt.show()

# %% [markdown]
# ## Origin - Quaternária

# %%
for idx, mat_content in enumerate(mat_contents_origin_qua):
    heatmap_print(idx, filenames_origin, mat_content)
# Out:
# Hypothesis1_Elec9
# Hypothesis1_Elec9-10-11
# Hypothesis1_Elec45
# Hypothesis1_Elec45-46-40
# Hypothesis1_Elec75
# Hypothesis1_Elec75-74-82
# Hypothesis1_Elec108
# Hypothesis1_Elec108-109-107
# Hypothesis2_Elec9
# Hypothesis2_Elec9-10-11
# Hypothesis2_Elec45
# Hypothesis2_Elec45-46-40
# Hypothesis2_Elec75
# Hypothesis2_Elec75-74-82
# Hypothesis2_Elec108
# Hypothesis2_Elec108-109-107
# Hypothesis3_Elec9
# Hypothesis3_Elec9-10-11
# Hypothesis3_Elec45
# Hypothesis3_Elec45-46-40
# Hypothesis3_Elec75
# Hypothesis3_Elec75-74-82
# Hypothesis3_Elec108
# Hypothesis3_Elec108-109-107

# %% [markdown]
# ## Orgin - Ternária

# %%
for idx, mat_content in enumerate(mat_contents_origin_ter):
    heatmap_print(idx, filenames_origin, mat_content)
# Out:
# Hypothesis1_Elec9
# Hypothesis1_Elec9-10-11
# Hypothesis1_Elec45
# Hypothesis1_Elec45-46-40
# Hypothesis1_Elec75
# Hypothesis1_Elec75-74-82
# Hypothesis1_Elec108
# Hypothesis1_Elec108-109-107
# Hypothesis2_Elec9
# Hypothesis2_Elec9-10-11
# Hypothesis2_Elec45
# Hypothesis2_Elec45-46-40
# Hypothesis2_Elec75
# Hypothesis2_Elec75-74-82
# Hypothesis2_Elec108
# Hypothesis2_Elec108-109-107
# Hypothesis3_Elec9
# Hypothesis3_Elec9-10-11
# Hypothesis3_Elec45
# Hypothesis3_Elec45-46-40
# Hypothesis3_Elec75
# Hypothesis3_Elec75-74-82
# Hypothesis3_Elec108
# Hypothesis3_Elec108-109-107

# %% [markdown]
# ## Pitch - Quaternária

# %%
for idx, mat_content in enumerate(mat_contents_pitch_qua):
    heatmap_print(idx, filenames_origin, mat_content)
# Out:
# Hypothesis1_Elec9
# Hypothesis1_Elec9-10-11
# Hypothesis1_Elec45
# Hypothesis1_Elec45-46-40
# Hypothesis1_Elec75
# Hypothesis1_Elec75-74-82
# Hypothesis1_Elec108
# Hypothesis1_Elec108-109-107
# Hypothesis2_Elec9
# Hypothesis2_Elec9-10-11
# Hypothesis2_Elec45
# Hypothesis2_Elec45-46-40
# Hypothesis2_Elec75
# Hypothesis2_Elec75-74-82
# Hypothesis2_Elec108
# Hypothesis2_Elec108-109-107
# Hypothesis3_Elec9
# Hypothesis3_Elec9-10-11
# Hypothesis3_Elec45
# Hypothesis3_Elec45-46-40
# Hypothesis3_Elec75
# Hypothesis3_Elec75-74-82
# Hypothesis3_Elec108
# Hypothesis3_Elec108-109-107

# %% [markdown]
# ## Pitch - Ternária

# %%
for idx, mat_content in enumerate(mat_contents_pitch_ter):
    heatmap_print(idx, filenames_origin, mat_content)
# Out:
# Hypothesis1_Elec9
# Hypothesis1_Elec9-10-11
# Hypothesis1_Elec45
# Hypothesis1_Elec45-46-40
# Hypothesis1_Elec75
# Hypothesis1_Elec75-74-82
# Hypothesis1_Elec108
# Hypothesis1_Elec108-109-107
# Hypothesis2_Elec9
# Hypothesis2_Elec9-10-11
# Hypothesis2_Elec45
# Hypothesis2_Elec45-46-40
# Hypothesis2_Elec75
# Hypothesis2_Elec75-74-82
# Hypothesis2_Elec108
# Hypothesis2_Elec108-109-107
# Hypothesis3_Elec9
# Hypothesis3_Elec9-10-11
# Hypothesis3_Elec45
